# %% [markdown]
# <a href="https://colab.research.google.com/github/KellyLee818/KellyLee818.github.io/blob/main/2026_09_16_UNHP_Chromosome_Base_Pairs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
chrom_data=pd.read_excel('/content/chrosome_basepairs.xlsx')

# %%
chrom_data
# Out:
#    chromosomes  basepais(bp)
# 0            1     248956422
# 1            2     242193529
# 2            3     198295559
# 3            4     190214555
# 4            5     181538259
# 5            6     170805979
# 6            7     159345973
# 7            8     145138636
# 8            9     138394717
# 9           10     133797422
# 10          11     135086622
# 11          12     133275309
# 12          13     114364328
# 13          14     107043718
# 14          15     101991189
# 15          16      90338345
# 16          17      83257441
# 17          18      80373285
# 18          19      58617616
# 19          20      46709983
# 20          21      46709983
# 21          22      50818468
# 22           X     156040895
# 23           Y      57227415

# %%
total_basepairs = chrom_data['basepais(bp)'].sum()
print(f"Total basepairs in the human genome: {total_basepairs}")
# Out:
# Total basepairs in the human genome: 3070535648

# %%
total_basepairs
# Out:
# np.int64(3070535648)

# %%
angstrom_per_basepair = 3.4
total_length_angstrom = total_basepairs * angstrom_per_basepair
print(f"Total length of all basepairs stretched out: {total_length_angstrom} Angstroms")
# Out:
# Total length of all basepairs stretched out: 10439821203.199999 Angstroms

# %%
print(f"Total length of all basepairs stretched out:{total_length_angstrom} Angstroms")
# Out:
# Total length of all basepairs stretched out:10439821203.199999 Angstroms

# %%
meters_per_angstrom = 1e-10
total_length_meters = total_length_angstrom * meters_per_angstrom
print(f"Total length of all basepairs stretched out: {total_length_meters} meters")
# Out:
# Total length of all basepairs stretched out: 1.04398212032 meters

# %%
print(f"Total length of all base pairs stretched out: {total_length_meters} meters")
# Out:
# Total length of all base pairs stretched out: 1.04398212032 meters

# %%
# Convert total basepairs to Megabasepairs (Mbps)
total_mbps = total_basepairs / 1_000_000
print(f"Total genome size: {total_mbps:.2f} Mbps")
# Out:
# Total genome size: 3070.54 Mbps

# %%
# Define costs per Mbps for given years
cost_per_mbps = {
    2001: 10000,   # $10,000 per Mbps
    2010: 1,       # $1 per Mbps
    2011: 0.10,    # $0.10 per Mbps
    2020: 0.01     # $0.01 per Mbps
}

# Calculate total cost for each year
costs = {}
for year, price_per_mbps in cost_per_mbps.items():
    costs[year] = total_mbps * price_per_mbps

# Display the calculated costs
for year, cost in costs.items():
    print(f"Total sequencing cost in {year}: ${cost:,.2f}")
# Out:
# Total sequencing cost in 2001: $30,705,356.48
# Total sequencing cost in 2010: $3,070.54
# Total sequencing cost in 2011: $307.05
# Total sequencing cost in 2020: $30.71

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
cost_df = pd.DataFrame(list(costs.items()), columns=['Year', 'Total_Cost'])

# Convert 'Year' to categorical for explicit treatment by seaborn
cost_df['Year'] = cost_df['Year'].astype(str)

# Plot the total cost changes over the years as a bar plot
fig = plt.figure(figsize=(12, 7)) # Slightly larger figure
ax = sns.barplot(x='Year', y='Total_Cost', data=cost_df, hue='Year', palette='viridis', legend=False)
plt.title('Human Genome Sequencing Cost Over Years')
plt.xlabel('Year')
plt.ylabel('Total Cost ($)')
plt.yscale('log') # Use a logarithmic scale due to large difference in costs
plt.grid(True, which="both", ls="--", c='0.7')
# The x-ticks will now be handled by seaborn as 'Year' is categorical
plt.tight_layout()

# Add text labels on top of each bar
for index, row in cost_df.iterrows():
    ax.text(index, row['Total_Cost'], f'${row['Total_Cost']:,.2f}', color='black', ha="center", va='bottom', fontsize=9)

plt.show()
